# %%
# %cd /content

# %%
# !git clone https://github.com/gkibria121/aasist.git
# Out:
# fatal: destination path 'aasist' already exists and is not an empty directory.

# %%
# %cd aasist
# !git pull
# Out:
# /content/aasist/aasist
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 4), reused 4 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (6/6), 828 bytes | 414.00 KiB/s, done.
# From https://github.com/gkibria121/aasist
#    fbbbd12..a91ee3b  main       -> origin/main
# Updating fbbbd12..a91ee3b
# Fast-forward
#  main.py | 89 +++++++++++++++++++++++++++--------------------------------------
#  1 file changed, 37 insertions(+), 52 deletions(-)

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
awsaf49_asvpoof_2019_dataset_path = kagglehub.dataset_download('awsaf49/asvpoof-2019-dataset')

print('Data source import complete.')
# Out:
# Using Colab cache for faster access to the 'asvpoof-2019-dataset' dataset.
# Data source import complete.

# %%
import os

src = os.path.join(awsaf49_asvpoof_2019_dataset_path, "LA", "LA")  # real folder
dst = "./LA"  # symlink to create in current directory

# Remove old symlink or folder if exists
if os.path.islink(dst) or os.path.exists(dst):
    os.remove(dst)

# Create symlink
os.symlink(src, dst, target_is_directory=True)

print("Symlink created:", dst, "→", src)
# Out:
# Symlink created: ./LA → /kaggle/input/asvpoof-2019-dataset/LA/LA

# %%
# !pip install -r requirements.txt

# %%
# !python main.py      --config ./config/SimpleCNN.conf   --analyze_db

# %%
# !python main.py    --output_dir ./exp_results --seed 1234  --config ./config/SimpleCNN.conf
# Out:
# 2025-12-05 11:00:54.680710: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764932454.700828   12660 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764932454.707000   12660 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764932454.723711   12660 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !cd ./LA && ls

# %%
# !python main.py  --eval    --config ./config/SimpleCNN.conf

# %%
# !zip -r ./exp_results/

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !cp LA_SimpleCNN_ep20_bs32.zip /content/drive/MyDrive/
