# %%
# !git clone https://github.com/gkibria121/aasist.git

# %%
# %cd aasist
# !git pull
# Out:
# /content/aasist
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 3 (delta 2), reused 3 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 613 bytes | 613.00 KiB/s, done.
# From https://github.com/gkibria121/aasist
#    7fa7672..a91ee3b  main       -> origin/main
# Updating 7fa7672..a91ee3b
# Fast-forward
#  main.py | 89 +++++++++++++++++++++++++++--------------------------------------
#  1 file changed, 37 insertions(+), 52 deletions(-)

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
awsaf49_asvpoof_2019_dataset_path = kagglehub.dataset_download('awsaf49/asvpoof-2019-dataset')

print('Data source import complete.')
# Out:
# Using Colab cache for faster access to the 'asvpoof-2019-dataset' dataset.
# Data source import complete.

# %%
import os

src = os.path.join(awsaf49_asvpoof_2019_dataset_path, "LA", "LA")  # real folder
dst = "./LA"  # symlink to create in current directory

# Remove old symlink or folder if exists
if os.path.islink(dst) or os.path.exists(dst):
    os.remove(dst)

# Create symlink
os.symlink(src, dst, target_is_directory=True)

print("Symlink created:", dst, "→", src)
# Out:
# Symlink created: ./LA → /kaggle/input/asvpoof-2019-dataset/LA/LA

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (2.9.0+cu126)
# Requirement already satisfied: torchcontrib in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (0.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (2.0.2)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (0.13.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->-r requirements.txt (line 1)) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->-r requirements.txt (line 1)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->-r requirements.txt (line 1)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->-r requirements.txt (line 1)) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->-r requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->-r requirements.txt (line 1)) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->-r requirements.txt (line 1)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->-r requirements.txt (line 1)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->-r requirements.txt (line 1)) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->-r requirements.txt (line 1)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->-r requirements.txt (line 1)) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->-r requirements.txt (line 1)) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->-r requirements.txt (line 1)) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->-r requirements.txt (line 1)) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->-r requirements.txt (line 1)) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->-r requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->-r requirements.txt (line 1)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->-r requirements.txt (line 1)) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->-r requirements.txt (line 1)) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->-r requirements.txt (line 1)) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->-r requirements.txt (line 1)) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->-r requirements.txt (line 1)) (3.5.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile->-r requirements.txt (line 4)) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile->-r requirements.txt (line 4)) (2.23)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.6.0->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.6.0->-r requirements.txt (line 1)) (3.0.3)

# %%
# !cd ./LA && ls
# Out:
# ASVspoof2019_LA_asv_protocols  ASVspoof2019_LA_dev    README.LA.txt
# ASVspoof2019_LA_asv_scores     ASVspoof2019_LA_eval
# ASVspoof2019_LA_cm_protocols   ASVspoof2019_LA_train

# %%
# !python main.py    --output_dir ./exp_results --seed 1234  --config ./config/SimpleCNN.conf
# Out:
# 2025-12-05 10:35:10.831032: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764930910.863173    6055 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764930910.873041    6055 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764930910.895108    6055 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764930910.895160    6055 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764930910.895168    6055 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764930910.895175    6055 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-05 10:35:10.902373: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Device: cuda
#
# ============================================================
# SAFE OPTIMIZATIONS ENABLED:
# ============================================================
# ============================================================
#
# Number of model parameters: 67490
# Loading datasets...
# Number of training files: 25380
# Number of validation files: 24844
# ✓ Datasets loaded. Training batches: 793
#
# ============================================================
# STARTING TRAINING
# Epochs: 20
# ============================================================
#
#
# ============================================================
# Epoch 1/20
# ============================================================
#
# 🚀 Training...
#    ✓ Training completed in 70.5s
#    📊 Training Loss: 0.4349
#
# 📊 Validating...
#    ✓ Validation completed in 124.1s
#
# 📈 Epoch 1 Summary:
#    EER:        16.523%
#    t-DCF:      0.47765
#    Acc@EER:    83.48%
#    Acc@t-DCF:  71.74%
#    Max Acc:    92.78%
#    Total Time: 194.6s
#
# ============================================================
# Epoch 2/20
# ============================================================
#
# 🚀 Training...
#    ✓ Training completed in 77.2s
#    📊 Training Loss: 0.2823
#
# 📊 Validating...
#    ✓ Validation completed in 61.9s
#
# 📈 Epoch 2 Summary:
#    EER:        9.970%
#    t-DCF:      0.29034
#    Acc@EER:    90.03%
#    Acc@t-DCF:  85.40%
#    Max Acc:    94.56%
#    Total Time: 139.0s
#
# ============================================================
# Epoch 3/20
# ============================================================
#
# 🚀 Training...
#    ✓ Training completed in 63.9s
#    📊 Training Loss: 0.2238
#
# 📊 Validating...
#    ✓ Validation completed in 60.2s
#
# 📈 Epoch 3 Summary:
#    EER:        10.715%
#    t-DCF:      0.32921
#    Acc@EER:    89.29%
#    Acc@t-DCF:  82.64%
#    Max Acc:    94.86%
#    Total Time: 124.1s
#
# ============================================================
# Epoch 4/20
# ============================================================
#
# 🚀 Training...
#    ✓ Training completed in 62.4s
#    📊 Training Loss: 0.1713
#
# 📊 Validating...
#    ✓ Validation completed in 60.9s
#
# 📈 Epoch 4 Summary:
#    EER:        7.184%
#    t-DCF:      0.21575
#    Acc@EER:    92.82%
#    Acc@t-DCF:  88.79%
#    Max Acc:    95.93%
#    Total Time: 123.3s
#
# ============================================================
# Epoch 5/20
# ============================================================
#
# 🚀 Training...
#    ✓ Training completed in 67.7s
#    📊 Training Loss: 0.1449
#
# 📊 Validating...
#    ✓ Validation completed in 61.4s
#
# 📈 Epoch 5 Summary:
#    EER:        8.908%
#    t-DCF:      0.28336
#    Acc@EER:    91.09%
#    Acc@t-DCF:  85.06%
#    Max Acc:    96.37%
#    Total Time: 129.1s
#
# ============================================================
# Epoch 6/20
# ============================================================
#
# 🚀 Training...
# Training:  86% 684/793 [00:53<00:08, 12.76it/s, loss=0.1318, lr=0.000805]Exception ignored in: <generator object tqdm.__iter__ at 0x7e32bac47880>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/std.py", line 1196, in __iter__
#     self.close()
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/std.py", line 1265, in close
#     def close(self):
#
# KeyboardInterrupt:
# Traceback (most recent call last):
#   File "/content/aasist/main.py", line 498, in <module>
#     main(parser.parse_args())
#   File "/content/aasist/main.py", line 159, in main
#     running_loss = train_epoch(trn_loader, model, optimizer, device,
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/aasist/main.py", line 441, in train_epoch
#     _, batch_out = model(batch_x, Freq_aug=str_to_bool(config["freq_aug"]))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1775, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1786, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/aasist/models/SimpleCNN.py", line 62, in forward
#     x = self.bn2(x)
#         ^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1775, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1786, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/batchnorm.py", line 173, in forward
#     self.num_batches_tracked.add_(1)  # type: ignore[has-type]
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt

# %%
# !python main.py  --eval    --config ./config/SimpleCNN.conf

# %%
# !zip -r ./exp_results/
# Out:
# config.conf
# events.out.tfevents.1764929678.eaa1e4de6023.850.0
# events.out.tfevents.1764930108.eaa1e4de6023.2649.0
# events.out.tfevents.1764930831.eaa1e4de6023.5670.0
# events.out.tfevents.1764930916.eaa1e4de6023.6055.0
# metric_log.txt
# metrics
# weights

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !cp LA_SimpleCNN_ep20_bs32.zip /content/drive/MyDrive/
